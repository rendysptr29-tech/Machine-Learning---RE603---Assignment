# %% [markdown]
# # **Primitive Data Types**

# %% [markdown]
# ## **Integer**

# %%
x = 175
y = 22

print(x)
# Out:
# 175

# %%
x = 120
y = 10

print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ##**Float**

# %%
x = 2.20
y = 3.1
z = -25.1

print(type(z))
print(z)
# Out:
# <class 'float'>
# -25.1

# %% [markdown]
# ## **Complex**

# %%
z = 4 + 8j
print(z)
print(z.real)
print(z.imag)
# Out:
# (4+8j)
# 4.0
# 8.0

# %% [markdown]
# ## **String**

# %%
a = "Hello world this is my first program!"

print(a)
print(type(a))
# Out:
# Hello world this is my first program!
# <class 'str'>

# %% [markdown]
# ## **Boolean**

# %%
b = True
a = False
print(a)
print(b)
# Out:
# False
# True

# %% [markdown]
# # Non-Primitive Data Types

# %% [markdown]
# ## **List**

# %% [markdown]
# Membuat List

# %%
huruf = ["f", "e", "d", "c", "b", "a"]

print(huruf[1:4])
# Out:
# ['e', 'd', 'c']

# %%
numbers = [1, 2, 3, 4, 5]

mixed = [13, "C++", 2.01, False]

print(numbers)
print(mixed)
# Out:
# [1, 2, 3, 4, 5]
# [13, 'C++', 2.01, False]

# %% [markdown]
# Mnegakses Elemen List

# %%
fruits = ["Start fruits", "Peanuts", "Mango"]

print(fruits[0])
print(fruits[1])
print(fruits[-1])
# Out:
# Start fruits
# Peanuts
# Mango

# %% [markdown]
# Mengubah Elemen List

# %%
fruits[1] = "Peanuts"
print(fruits)
# Out:
# ['Start fruits', 'Peanuts', 'Start fruits']

# %% [markdown]
# Menambahkan Elemen ke List

# %%
fruits.append("Banana")
print(fruits)

fruits.insert(1, "Cherry")
print(fruits)
# Out:
# ['Start fruits', 'Cherry', 'Cherry', 'Cherry', 'Cherry', 'Grapes', 'Peanuts', 'Start fruits', 'Orange', 'Banana', 'Cherry', 'Banana', 'Banana', 'Banana', 'Banana', 'Banana']
# ['Start fruits', 'Cherry', 'Cherry', 'Cherry', 'Cherry', 'Cherry', 'Grapes', 'Peanuts', 'Start fruits', 'Orange', 'Banana', 'Cherry', 'Banana', 'Banana', 'Banana', 'Banana', 'Banana']

# %% [markdown]
# Menghapus Elemen List

# %%
fruits.remove("Peanuts")
print(fruits)

fruits.pop(2)
print(fruits)

del fruits[1]
print(fruits)
# Out:
# ['Start fruits', 'Cherry', 'Cherry', 'Cherry', 'Cherry', 'Cherry', 'Grapes', 'Start fruits', 'Orange', 'Banana', 'Cherry', 'Banana', 'Banana', 'Banana', 'Banana', 'Banana']
# ['Start fruits', 'Cherry', 'Cherry', 'Cherry', 'Cherry', 'Grapes', 'Start fruits', 'Orange', 'Banana', 'Cherry', 'Banana', 'Banana', 'Banana', 'Banana', 'Banana']
# ['Start fruits', 'Cherry', 'Cherry', 'Cherry', 'Grapes', 'Start fruits', 'Orange', 'Banana', 'Cherry', 'Banana', 'Banana', 'Banana', 'Banana', 'Banana']

# %% [markdown]
# Menggunakan Loop pada List

# %%
for fruit in fruits:
    print(fruit)
# Out:
# Start fruits
# Cherry
# Cherry
# Cherry
# Grapes
# Start fruits
# Orange
# Banana
# Cherry
# Banana
# Banana
# Banana
# Banana
# Banana

# %% [markdown]
# Kesimpulan:
#
# 1. List menyimpan banyak nilai dalam satu variabel
# 2. Bisa diakses, diubah, ditambah, dan dihapus
# 3. Loop dan List Comprehension membuatnya lebih fleksibel

# %% [markdown]
# ## **Tuple**

# %%
numbers = (5, 4, 3, 2, 1)

mixed = (10, "C++", 3.14, False)

print(numbers)
print(mixed)
# Out:
# (5, 4, 3, 2, 1)
# (10, 'C++', 3.14, False)

# %% [markdown]
# Jika hanya satu elemen dalam tuple, tambahkan koma , agar Python mengenali sebagai tuple.

# %%
single_element = (3.1,)
not_tuple = (1)

print(type(single_element))
print(type(not_tuple))
# Out:
# <class 'tuple'>
# <class 'int'>

# %% [markdown]
# Mengakses Elemen Tuple

# %%
fruits = ("Peanuts", "Mango", "Banana")

print(fruits[0])
print(fruits[-1])
# Out:
# Peanuts
# Banana

# %% [markdown]
# Tuple tidak bisa diubah jika sudah dibuat, contoh:

# %% [markdown]
# tidak seperti list yang bisa diubah

# %%
fruits[-1]
# Out:
# 'Banana'

# %% [markdown]
#  Bisa Menyimpan Banyak Nilai Sekaligus (Packing & Unpacking)

# %%
data = ("Rendi", 21, "Robotics Engineering, A Class")

name, age, job = data

print(name)
print(age)
print(job)
# Out:
# Rendi
# 21
# Robotics Engineering, A Class

# %% [markdown]
# Menggabungkan Tuple

# %%
tuple2 = (4, 5, 6)
tuple1 = (1, 2, 3)

new_tuple = tuple1 + tuple2
print(new_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# Menghitung Elemen dalam Tuple

# %%
numbers = (1, 2, 2, 3, 4, 2, 5)

print(numbers.count(2))
print(numbers.index(3))
# Out:
# 3
# 3

# %% [markdown]
# Kesimpulan:
#
# 1. Tuple mirip list, tetapi immutable (tidak bisa diubah).
# 2. Lebih cepat dan aman dibanding list jika datanya tetap.
# 3. Bisa digunakan untuk menyimpan data yang tidak boleh berubah.

# %% [markdown]
# ### Hands On

# %%
lokasi = (12.5, -7.8, 100.2)

print("Koordinat awal:", lokasi)
# Out:
# Koordinat awal: (12.5, -7.8, 100.2)

# %%
lokasi[0] = 15.0  # Apakah ini berhasil?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 lokasi[0] = 15.0  # Apakah ini berhasil?
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## **Dictionary**

# %% [markdown]
# Membuat Dictionary

# %%
student = {
    "nama": "Rendi Rahmat Saputra",
    "umur": 21,
    "jurusan": "Artificial Intelligence (AI)"
}

print(student)
# Out:
# {'nama': 'Rendi Rahmat Saputra', 'umur': 21, 'jurusan': 'Artificial Intelligence (AI)'}

# %% [markdown]
# Dictionary menggunakan kurung kurawal {}.

# %% [markdown]
# Mengakses Nilai dalam Dictionary

# %%
print(student["nama"])
print(student["umur"])
# Out:
# Rendi Rahmat Saputra
# 21

# %% [markdown]
# Menambahkan atau Mengubah Data dalam Dictionary

# %%
student["alamat"] = "Kota Batam"

student["umur"] = 21

print(student)
# Out:
# {'nama': 'Rendi Rahmat Saputra', 'umur': 21, 'jurusan': 'Artificial Intelligence (AI)', 'alamat': 'Kota Batam'}

# %% [markdown]
# menghapus elemen dalam dictionary

# %%
del student["jurusan"]

umur = student.pop("umur")

print(student)
print(umur)
# Out:
# {'nama': 'Rendi Rahmat Saputra', 'alamat': 'Kota Batam'}
# 21

# %% [markdown]
# Fungsi pop() pada dictionary digunakan untuk menghapus sebuah key dan mengembalikan nilai (value) yang dihapus.
# sedangkan "del" hanya menghapus tanpa menyimpan nilai

# %% [markdown]
# ## **Set**

# %%
angka = {5, 4, 6, 4, 7, 8}

huruf = {"a", "b", "c", "d"}

campuran = {2, "C++", 21.1}

print(angka)
print(huruf)
print(campuran)
# Out:
# {4, 5, 6, 7, 8}
# {'c', 'd', 'a', 'b'}
# {2, 21.1, 'C++'}

# %% [markdown]
# Ciri-ciri set:
# 1. Tidak ada elemen yang duplikat
# 2. Tidak memiliki indeks (tidak bisa diakses dengan angka index seperti list)

# %% [markdown]
# Menghapus Duplikat dari List dengan Set

# %%
angka_list = [5, 4, 6, 4, 7, 8, 9]
angka_set = set(angka_list)

print(angka_set)
# Out:
# {4, 5, 6, 7, 8, 9}

# %% [markdown]
# Menambah dan Menghapus Elemen Menggunakan Set

# %%
angka.add(4)
angka.remove(5)
print(angka)
# Out:
# {4, 6, 7, 8}

# %% [markdown]
# **Operasi Himpunan (set operations)**
# Irisan (Intersection)

# %%
a = {6, 5, 4, 3}
b = {4, 2, 1, 5}

print(a & b)
# Out:
# {4, 5}

# %% [markdown]
# Gabungan atau Union

# %%
print(a | b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
#  Selisih (Difference)

# %%
print(a - b)
print(b - a)
# Out:
# {3, 6}
# {1, 2}

# %% [markdown]
# Kesimpulan
# 1. set digunakan untuk menyimpan elemen unik
# 2. Tidak memiliki indeks atau urutan tetap
# 3. Cocok untuk operasi himpunan (union, intersection, dll.)
# 4. Berguna untuk menghapus duplikat dari list

# %%
id_pengguna = {101, 202, 303, 404}

print("Sebelum ditambah:", id_pengguna)
# Out:
# Sebelum ditambah: {202, 404, 101, 303}

# %% [markdown]
# ### Hands On
#
# Jika saya ingin menambahkan
# 1. id_pengguna.add(505) dan
# 2. id_pengguna.add(101)
# apa yang terjadi?

# %%
id_pengguna.add(505)
print("Setelah ditambah:", id_pengguna)
# Out:
# Setelah ditambah: {101, 202, 303, 404, 505}

# %%
id_pengguna.add(101)
print("Setelah ditambah:", id_pengguna)
# Out:
# Setelah ditambah: {101, 202, 303, 404, 505}

# %% [markdown]
# # Konversi Tipe Data

# %% [markdown]
# Konversi Otomatis (Implicit Conversion)

# %%
angka_int = 10
angka_float = angka_int + 1.2

print(angka_float)
print(type(angka_float))
# Out:
# 11.2
# <class 'float'>

# %% [markdown]
# Python mengubah 10 (int) menjadi 10.0 (float) agar sesuai dengan operasi float.

# %% [markdown]
# Konversi Manual (Explicit Conversion)

# %% [markdown]
# int ke float / float ke int

# %%
x = 9
x_float = float(x)

y = 4.2
y_int = int(y)

print(x_float)
print(y_int)
# Out:
# 9.0
# 4

# %% [markdown]
# int/float ke string

# %%
angka = 23
angka_str = str(angka)

teks = "90"
teks_int = int(teks)

print(angka_str, type(angka_str))
print(teks_int, type(teks_int))
# Out:
# 23 <class 'str'>
# 90 <class 'int'>

# %% [markdown]
# list ke tuple

# %%
data_list = [4, 5, 6]
data_tuple = tuple(data_list)
data_tuple2 = (1, 2, 3)
data_list2 = list(data_tuple2)

print(data_tuple, type(data_tuple))
print(data_list2, type(data_list2))
# Out:
# (4, 5, 6) <class 'tuple'>
# [1, 2, 3] <class 'list'>

# %% [markdown]
# list/tuple ke set

# %%
angka_list = [4, 5, 5, 6]
angka_set = set(angka_list)

angka_tuple = tuple(angka_set)

print(angka_set)
print(angka_tuple)
# Out:
# {4, 5, 6}
# (4, 5, 6)

# %% [markdown]
# Dictionary ke Lis

# %%
data_dict = {"nama": "Rendi", "umur": 21}

keys_list = list(data_dict.keys())

values_list = list(data_dict.values())

print(keys_list)
print(values_list)
# Out:
# ['nama', 'umur']
# ['Rendi', 21]

# %% [markdown]
# Kesimpulan:
#
# 1. Konversi Otomatis terjadi saat Python perlu menyamakan tipe data dalam operasi.
# 2. Konversi Manual (Casting) dilakukan dengan fungsi bawaan (int(), float(), str(), list(), dll.).
# 3. Gunakan konversi yang tepat sesuai kebutuhan, terutama untuk menghindari error saat operasi antar tipe data.
